# %% [markdown]
# <a href="https://colab.research.google.com/github/Mauzz333/HANDS-ON_Fundamentos-de-Programacion-con-Python/blob/main/Marketing_Bancario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df_bank = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/bank-additional.csv')

# %%
#Geración de reporte

bank_report = ProfileReport(df_bank, title = 'Bank Data Profile')
bank_report.to_file(output_file= 'Report_Bank_Marketing.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from google.colab import files

# Ejecute esta celda para descargar reporte directamente aquí.
files.download('Report_Bank_Marketing.html')
